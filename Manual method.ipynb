# %%
import random
class FakeLLM:

    def __init__(self):
        print('LLm created')
    
    def predict(self, prompt):
        response_list= [
            'Delhi is the capital of India',
            'IPL is a cricket league',
            'AI stands for Artificaial intelligence.'
        ]
        return {'response': random.choice(response_list)}

# %%
llm = FakeLLM()
# Out:
# LLm created

# %%
llm.predict('what is the Capital of India')
# Out:
# {'response': 'AI stands for Artificaial intelligence.'}

# %%
class FakePromptTemplate:
    
    def __init__(self, template, input_variables) :
        self.template = template
        self.input_variables = input_variables
        
    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
template = FakePromptTemplate(
    template='write a {length} poem on {topic}',
    input_variables=['length', 'topic']
)

# %%
prompt = template.format({'length': 'short','topic': 'india'})

# %%
llm = FakeLLM()
# Out:
# LLm created

# %%
llm.predict(prompt)
# Out:
# {'response': 'AI stands for Artificaial intelligence.'}

# %%
class FakeLLMChain:
    
    def __init__(self,llm,prompt):
        self.llm = llm
        self.prompt = prompt
        
    def run(self, input_dic):
        final_prompt = self.prompt.format(input_dic)
        result = self.llm.predict(final_prompt)
        
        return result['response']

# %%
template = FakePromptTemplate(
    template='write a {length} poem on {topic}',
    input_variables=['length', 'topic']
)

# %%
llm = FakeLLM()
# Out:
# LLm created

# %%
chain = FakeLLMChain(llm, template)

chain.run({'length':'short','topic':'india'})
# Out:
# 'IPL is a cricket league'
